# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.messages import HumanMessage
from IPython.display import Markdown
# Out:
# c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\checkpoint\serde\encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
load_dotenv(override=True)
# Out:
# True

# %%
mcp_client = MultiServerMCPClient({
    "mcp-server": {
        "transport": "streamable_http",
        "url": "http://localhost:24000/mcp"
    }
})

# %%
tools = await mcp_client.get_tools()

# %%
tools
# Out:
# [StructuredTool(name='get_employee_infos', description='Get info about the given employee', args_schema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_employee_infosArguments', 'type': 'object'}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C9CC9AE020>),
#  StructuredTool(name='search', description='Search web for the given query', args_schema={'properties': {'query': {'title': 'Query', 'type': 'string'}}, 'required': ['query'], 'title': 'searchArguments', 'type': 'object'}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C9CCA9DDA0>)]

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
agent = create_agent(
    model=llm, tools=tools, system_prompt="answer user question using provided tools"
)

# %%
resp = await agent.ainvoke({
    "messages" : [
        HumanMessage("Quel est le salaire de Hassan")
    ]
})
# Out:
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_transports\default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     135         await self._response_closed()
# --> 136 raise exc
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\http11.py:86, in AsyncHTTP11Connection.handle_async_request(self, request)
#      83 async with Trace(
#      84     "send_request_headers", logger, request, kwargs
#      85 ) as trace:
# ---> 86     await self._send_request_headers(**kwargs)
#      87 async with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_async\http11.py:144, in AsyncHTTP11Connection._send_request_headers(self, request)
#     142 timeout = timeouts.get("write", None)
# --> 144 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     145     event = h11.Request(
#     146         method=request.method,
#     147         target=request.url.target,
#     148         headers=request.headers,
#     149     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer 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\n'
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_base_client.py:1648, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1647 try:
# -> 1648     response = await self._send_request(
#    1649         request,
#    1650         stream=stream or self._should_stream_response_body(request=request),
#    1651         **kwargs,
#    1652     )
#    1653 except httpx.TimeoutException as err:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_client.py:946, in AsyncOpenAI._send_request(self, request, stream, **kwargs)
#     938 @override
#     939 async def _send_request(
#     940     self,
#    (...)    944     **kwargs: Unpack[HttpxSendArgs],
#     945 ) -> httpx.Response:
# --> 946     return await self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_client.py:924, in AsyncOpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     922         used_workload_identity_auth = True
# --> 924 response = await super()._send_request(request, stream=stream, **kwargs)
#     925 if (
#     926     response.status_code == 401
#     927     and self._workload_identity_auth is not None
#     928     and used_workload_identity_auth
#     929     and not retried
#     930 ):
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_base_client.py:1571, in AsyncAPIClient._send_request(self, request, stream, **kwargs)
#    1564 async def _send_request(
#    1565     self,
#    1566     request: httpx.Request,
#    (...)   1569     **kwargs: Unpack[HttpxSendArgs],
#    1570 ) -> httpx.Response:
# -> 1571     return await self._client.send(request, stream=stream, **kwargs)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_transports\default.py:393, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
# --> 393 with map_httpcore_exceptions():
#     394     resp = await self._pool.handle_async_request(req)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer 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\n'
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 resp = await agent.ainvoke({
#       2     "messages" : [
#       3         HumanMessage("Quel est le salaire de Hassan")
#       4     ]
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\pregel\main.py:3535, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3532             chunks.append(chunk)
#    3533 else:
#    3534     # v1: collect interrupts from updates stream
# -> 3535     async for chunk in self.astream(
#    3536         input,
#    3537         config,
#    3538         context=context,
#    3539         stream_mode=(
#    3540             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3541         ),
#    3542         print_mode=print_mode,
#    3543         output_keys=output_keys,
#    3544         interrupt_before=interrupt_before,
#    3545         interrupt_after=interrupt_after,
#    3546         durability=durability,
#    3547         **kwargs,
#    3548     ):
#    3549         if stream_mode == "values":
#    3550             if len(chunk) == 2:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\pregel\main.py:3181, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    3179 for task in await loop.amatch_cached_writes():
#    3180     loop.output_writes(task.id, task.writes, cached=True)
# -> 3181 async for _ in runner.atick(
#    3182     [t for t in loop.tasks.values() if not t.writes],
#    3183     timeout=self.step_timeout,
#    3184     get_waiter=get_waiter,
#    3185     schedule_task=loop.aaccept_push,
#    3186 ):
#    3187     # emit output
#    3188     for o in _output(
#    3189         stream_mode,
#    3190         print_mode,
#    (...)   3196         _state_mapper,
#    3197     ):
#    3198         yield o
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\pregel\_retry.py:242, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     240         break
#     241     else:
# --> 242         return await task.proc.ainvoke(task.input, config)
#     243 except ParentCommand as exc:
#     244     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     703     # run in context
#     704     with set_config_context(config, run) as context:
# --> 705         input = await asyncio.create_task(
#     706             step.ainvoke(input, config, **kwargs), context=context
#     707         )
#     708 else:
#     709     input = await step.ainvoke(input, config, **kwargs)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     471         await run_manager.on_chain_end(ret)
#     472 else:
# --> 473     ret = await self.afunc(*args, **kwargs)
#     474 if self.recurse and isinstance(ret, Runnable):
#     475     return await ret.ainvoke(input, config)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain\agents\factory.py:1365, in create_agent.<locals>.amodel_node(state, runtime)
#    1353 request = ModelRequest(
#    1354     model=model,
#    1355     tools=default_tools,
#    (...)   1361     runtime=runtime,
#    1362 )
#    1364 if awrap_model_call_handler is None:
# -> 1365     model_response = await _execute_model_async(request)
#    1366     return _build_commands(model_response)
#    1368 result = await awrap_model_call_handler(request, _execute_model_async)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain\agents\factory.py:1337, in create_agent.<locals>._execute_model_async(request)
#    1334 if request.system_message:
#    1335     messages = [request.system_message, *messages]
# -> 1337 output = await model_.ainvoke(messages)
#    1338 if name:
#    1339     output.name = name
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_core\runnables\base.py:5766, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5759 @override
#    5760 async def ainvoke(
#    5761     self,
#    (...)   5764     **kwargs: Any | None,
#    5765 ) -> Output:
# -> 5766     return await self.bound.ainvoke(
#    5767         input,
#    5768         self._merge_configs(config),
#    5769         **{**self.kwargs, **kwargs},
#    5770     )
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:495, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     485 @override
#     486 async def ainvoke(
#     487     self,
#    (...)    492     **kwargs: Any,
#     493 ) -> AIMessage:
#     494     config = ensure_config(config)
# --> 495     llm_result = await self.agenerate_prompt(
#     496         [self._convert_input(input)],
#     497         stop=stop,
#     498         callbacks=config.get("callbacks"),
#     499         tags=config.get("tags"),
#     500         metadata=config.get("metadata"),
#     501         run_name=config.get("run_name"),
#     502         run_id=config.pop("run_id", None),
#     503         **kwargs,
#     504     )
#     505     return cast(
#     506         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     507     )
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1763, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1754 @override
#    1755 async def agenerate_prompt(
#    1756     self,
#    (...)   1760     **kwargs: Any,
#    1761 ) -> LLMResult:
#    1762     prompt_messages = [p.to_messages() for p in prompts]
# -> 1763     return await self.agenerate(
#    1764         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1765     )
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1721, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1708     if run_managers:
#    1709         await asyncio.gather(
#    1710             *[
#    1711                 run_manager.on_llm_end(
#    (...)   1719             ]
#    1720         )
# -> 1721     raise exceptions[0]
#    1722 flattened_outputs = [
#    1723     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1724     for res in results
#    1725 ]
#    1726 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2056, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2054     result = generate_from_stream(iter(chunks))
#    2055 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 2056     result = await self._agenerate(
#    2057         messages, stop=stop, run_manager=run_manager, **kwargs
#    2058     )
#    2059 else:
#    2060     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1925, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#    1923     _handle_openai_bad_request(e)
#    1924 except openai.APIError as e:
# -> 1925     _handle_openai_api_error(e)
#    1926 except Exception as e:
#    1927     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1918, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#    1911         return _construct_lc_result_from_responses_api(
#    1912             response,
#    1913             schema=original_schema_obj,
#    1914             metadata=generation_info,
#    1915             output_version=self.output_version,
#    1916         )
#    1917     else:
# -> 1918         raw_response = await self.async_client.with_raw_response.create(
#    1919             **payload
#    1920         )
#    1921         response = raw_response.parse()
#    1922 except openai.BadRequestError as e:
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_legacy_response.py:384, in async_to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     380 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     382 kwargs["extra_headers"] = extra_headers
# --> 384 return cast(LegacyAPIResponse[R], await func(*args, **kwargs))
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:2739, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2692 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2693 async def create(
#    2694     self,
#    (...)   2736     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2737 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2738     validate_response_format(response_format)
# -> 2739     return await self._post(
#    2740         "/chat/completions",
#    2741         body=await async_maybe_transform(
#    2742             {
#    2743                 "messages": messages,
#    2744                 "model": model,
#    2745                 "audio": audio,
#    2746                 "frequency_penalty": frequency_penalty,
#    2747                 "function_call": function_call,
#    2748                 "functions": functions,
#    2749                 "logit_bias": logit_bias,
#    2750                 "logprobs": logprobs,
#    2751                 "max_completion_tokens": max_completion_tokens,
#    2752                 "max_tokens": max_tokens,
#    2753                 "metadata": metadata,
#    2754                 "modalities": modalities,
#    2755                 "n": n,
#    2756                 "parallel_tool_calls": parallel_tool_calls,
#    2757                 "prediction": prediction,
#    2758                 "presence_penalty": presence_penalty,
#    2759                 "prompt_cache_key": prompt_cache_key,
#    2760                 "prompt_cache_retention": prompt_cache_retention,
#    2761                 "reasoning_effort": reasoning_effort,
#    2762                 "response_format": response_format,
#    2763                 "safety_identifier": safety_identifier,
#    2764                 "seed": seed,
#    2765                 "service_tier": service_tier,
#    2766                 "stop": stop,
#    2767                 "store": store,
#    2768                 "stream": stream,
#    2769                 "stream_options": stream_options,
#    2770                 "temperature": temperature,
#    2771                 "tool_choice": tool_choice,
#    2772                 "tools": tools,
#    2773                 "top_logprobs": top_logprobs,
#    2774                 "top_p": top_p,
#    2775                 "user": user,
#    2776                 "verbosity": verbosity,
#    2777                 "web_search_options": web_search_options,
#    2778             },
#    2779             completion_create_params.CompletionCreateParamsStreaming
#    2780             if stream
#    2781             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2782         ),
#    2783         options=make_request_options(
#    2784             extra_headers=extra_headers,
#    2785             extra_query=extra_query,
#    2786             extra_body=extra_body,
#    2787             timeout=timeout,
#    2788             security={"bearer_auth": True},
#    2789         ),
#    2790         cast_to=ChatCompletion,
#    2791         stream=stream or False,
#    2792         stream_cls=AsyncStream[ChatCompletionChunk],
#    2793     )
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\user\mcp-demo-mcp\.venv\Lib\site-packages\openai\_base_client.py:1683, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1680         continue
#    1682     log.debug("Raising connection error")
# -> 1683     raise APIConnectionError(request=request) from err
#    1685 log.debug(
#    1686     'HTTP Response: %s %s "%i %s" %s',
#    1687     request.method,
#    (...)   1691     response.headers,
#    1692 )
#    1693 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
# During task with name 'model' and id '869d49d5-14d7-f27f-1c7a-5eaf238703ab'

# %%
print(resp['messages'][-1].content)

# %%
resp = await agent.ainvoke({
    "messages" : [
        HumanMessage("Quel est la valeur de l'action de microsoft aujourd'hui")
    ]
})

# %%
print(display(Markdown(resp['messages'][-1].content)))
